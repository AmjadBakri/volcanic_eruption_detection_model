# %%
import pandas as pd
import os
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras.layers import Dense, Flatten, Dropout, BatchNormalization, Conv2D, MaxPooling2D
from keras import Sequential, Input, Model
from sklearn.model_selection import KFold
from tensorflow.keras import Sequential
from tensorflow.keras.losses import MeanSquaredError, BinaryCrossentropy,SparseCategoricalCrossentropy
from tensorflow.keras.activations import sigmoid
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from sklearn.metrics import accuracy_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.svm import LinearSVC
from sklearn.utils import shuffle
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
import statsmodels.api as sm
from sklearn import metrics
from skimage.io import imread
from skimage.transform import resize
import warnings
from tensorflow.keras.preprocessing.image import ImageDataGenerator
warnings.filterwarnings(action='ignore')
sns.set()

# %%
from PIL import Image, ImageFile
ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# # prepare for data augmentation

# %%
datagen = ImageDataGenerator(
    rotation_range = 45,
    rescale=1./255,
    width_shift_range = 0.2,
    height_shift_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'reflect')

# %% [markdown]
# # data path

# %%
train_path = "training"
test_path = "validation"

# %% [markdown]
# # Load data
# I can augment data directly but i choose to save it then no need to augment it again

# %%
image_shape = (224,224,3)
BATCH_SIZE = 8


train_datagen = datagen
train_generator = train_datagen.flow_from_directory(train_path,
                                                   batch_size = BATCH_SIZE,
                                                   target_size = (224,224),
                                                   class_mode = 'categorical')

test_datagen = datagen
test_generator = test_datagen.flow_from_directory(test_path,
                                                   batch_size = BATCH_SIZE,
                                                   target_size = (224,224),
                                                   class_mode = 'categorical')
# Out:
# Found 6038 images belonging to 2 classes.
# Found 167 images belonging to 2 classes.

# %% [markdown]
# # Load model already Created and Trained before and Evaluate It

# %%
model = tf.keras.models.load_model("beta_model")

# %%
model.evaluate(train_generator)
# Out:
# 1208/1208 [==============================] - 83s 68ms/step - loss: 0.0069 - accuracy: 0.9992 - auc: 0.9998
# [0.006852393038570881, 0.9991719126701355, 0.999832272529602]

# %%
model.evaluate(test_generator)
# Out:
# 34/34 [==============================] - 3s 87ms/step - loss: 0.4021 - accuracy: 0.8982 - auc: 0.9198
# [0.40208831429481506, 0.8982036113739014, 0.9198249578475952]

# %% [markdown]
# # Train the last layers in the Pretrained models

# %%
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3), include_top=False)
base_model.trainable = False

x = Flatten()(base_model.output)
x = Dense(16, activation='relu',kernel_regularizer=tf.keras.regularizers.L2(0.001))(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(
    loss = BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.00001),
    metrics=['accuracy', 'AUC']
)
history=model.fit(
    train_generator,            
    epochs=3,
    validation_data=(test_generator),
)
# Out:
# Epoch 1/3
# 755/755 [==============================] - 91s 118ms/step - loss: 0.3975 - accuracy: 0.8347 - auc: 0.9176 - val_loss: 0.3537 - val_accuracy: 0.8623 - val_auc: 0.9362
# Epoch 2/3
# 755/755 [==============================] - 85s 112ms/step - loss: 0.2406 - accuracy: 0.9152 - auc: 0.9742 - val_loss: 0.3283 - val_accuracy: 0.8623 - val_auc: 0.9456
# Epoch 3/3
# 755/755 [==============================] - 84s 111ms/step - loss: 0.1738 - accuracy: 0.9503 - auc: 0.9896 - val_loss: 0.3322 - val_accuracy: 0.8862 - val_auc: 0.9408

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
model.save("MobileNetV2")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 53). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: MobileNetV2\assets
# INFO:tensorflow:Assets written to: MobileNetV2\assets

# %%
del model,history

# %%
base_model = tf.keras.applications.DenseNet121(input_shape=(224, 224, 3), include_top=False)
base_model.trainable = False
x = Flatten()(base_model.output)
x = Dense(64, activation='relu')(x)
output = Dense(2, activation='softmax')(x)

model = Model(inputs=base_model.input, outputs=output)
model.compile(
    loss = BinaryCrossentropy(),
    optimizer = tf.keras.optimizers.Adam(learning_rate=0.0001),
    metrics=['accuracy', 'AUC']
)
history=model.fit(
    train_generator,            
    epochs=2,
    validation_data=(test_generator),
)
# Out:
# Epoch 1/2
# 755/755 [==============================] - 339s 443ms/step - loss: 0.2932 - accuracy: 0.8702 - auc: 0.9476 - val_loss: 0.3177 - val_accuracy: 0.8743 - val_auc: 0.9356
# Epoch 2/2
# 755/755 [==============================] - 321s 426ms/step - loss: 0.1432 - accuracy: 0.9440 - auc: 0.9870 - val_loss: 0.3343 - val_accuracy: 0.8743 - val_auc: 0.9211

# %%
model.fit(
    train_generator,            
    epochs=1,
    validation_data=(test_generator),
)
# Out:
# 755/755 [==============================] - 329s 436ms/step - loss: 0.0810 - accuracy: 0.9727 - auc: 0.9967 - val_loss: 0.2722 - val_accuracy: 0.8982 - val_auc: 0.9577

# %%
model.save("DenseNet121")
# Out:
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 121). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: DenseNet121\assets
# INFO:tensorflow:Assets written to: DenseNet121\assets

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# Plot the training and validation loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %% [markdown]
# # evaluate the model

# %%
x_val = []
y_val = []

# %%
for i in range(len(test_generator)):
    test_data = test_generator.next()
    x_val.append(test_data[0])
    y_val.append(test_data[1])
x_val = np.concatenate(x_val)
y_val = np.concatenate(y_val)

# %%
x_val=np.array(x_val)
y_val=np.array(y_val)

# %%
x_val.shape
# Out:
# (167, 224, 224, 3)

# %%
y_val.shape
# Out:
# (167, 2)

# %%
predictions = model.predict(x_val)
# Out:
# 6/6 [==============================] - 8s 1s/step

# %%
predictions=predictions.argmax(axis=1)

# %%
report = classification_report (y_val[ : , 1], predictions)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.94      0.82      0.88        74
#          1.0       0.87      0.96      0.91        93
#
#     accuracy                           0.90       167
#    macro avg       0.91      0.89      0.90       167
# weighted avg       0.90      0.90      0.90       167

# %%
cf_matrix = confusion_matrix(y_val[ : , 1], predictions)

# %%
cf_matrix
# Out:
# array([[61, 13],
#        [ 4, 89]], dtype=int64)

# %%
sns.heatmap(cf_matrix/np.sum(cf_matrix), annot=True, fmt='.2%')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Test on a sample

# %%
for i in range(1,10):
    plt.subplots(figsize=(10, 10)) 
    plt.subplot(5, 5, i+1)
    test=(x_val[i].reshape((1, ) + x_val[i].shape))
    some = model.predict(test)
    if np.argmax(some)==0:
        plt.title("eruption")
    else:
        plt.title("no_eruption")
    plt.imshow(x_val[i])
    plt.subplots_adjust(wspace=0.3, hspace=0.5, left=0.1, right=0.9, top=0.9, bottom=0.1)
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 83ms/step
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 84ms/step
# 1/1 [==============================] - 0s 84ms/step
